# %% [markdown]
# #**Decisiones sobre estructura y documentación del módulo Data Science.**

# %% [markdown]
# Este documento tiene como objetivo explicar y justificar las decisiones tomadas
# respecto a la organización del repositorio y la forma de documentar el trabajo
# del equipo de Data Science dentro del proyecto FlightOnTime.
#
# El propósito es que todo el equipo comprenda estas decisiones y las utilice de
# forma consistente durante el desarrollo del hackathon.
#
# ---

# %% [markdown]
# ## **1. Estructura del repositorio de Data Science.**

# %% [markdown]
# Se definió una estructura de carpetas clara y simple, orientada a un MVP de
# hackathon y alineada con buenas prácticas de Data Science en entornos reales.
#
# La estructura busca:
# - Separar datos originales de datos procesados
# - Facilitar el trabajo colaborativo
# - Evitar errores comunes (como modificar datos originales)
# - Clarificar el rol del módulo de Data Science dentro del proyecto principal

# %% [markdown]
# ### **Definición de carpetas y subcarpetas.**
#
# - `data/raw/`
#   Contiene los datos originales sin ningún tipo de modificación.
#   Esta carpeta se conserva como fuente única de verdad.
#
# - `data/processed/`
#   Contiene copias de los datos ya limpios y preparados para el modelado.
#   Todas las transformaciones se realizan sobre estos archivos.
#
# - `notebooks/`
#   Espacio principal de trabajo del equipo de Data Science.
#   Aquí se desarrolla el flujo completo: exploración, preparación y entrenamiento.
#
# - `models/`
#   Contiene el modelo entrenado y serializado, listo para ser consumido por la API
#   del equipo de Back-End.
#
# - `src/`
#   Código reutilizable del proyecto (preprocesamiento, feature engineering y
#   funciones auxiliares), con el objetivo de evitar duplicación en notebooks.
#
# - `docs/`
#   Documentación de apoyo, organizada en:
#
#   *   `docs/justificacion/`: documentos que explican y fundamentan decisiones
#        conceptuales y técnicas.
#
#   *   `docs/documentacion/`: documentos formales que definen el problema,
#        el alcance y las reglas utilizadas en el proyecto.
#
#
# - `images/`
#   Recursos visuales utilizados en documentación y presentaciones.
#
# Esta estructura permite que cualquier integrante del equipo entienda rápidamente
# dónde trabajar y qué rol cumple cada carpeta.
#
#
# ---

# %% [markdown]
# ## **2. Alcance de la documentación.**

# %% [markdown]
# Se optó por una documentación **simple, centralizada y funcional**, evitando
# sobrecargar el repositorio.
#
# La documentación del módulo de Data Science debe incluir:

# %% [markdown]
# **Definición del problema de negocio.**
#
#
# *   ¿Qué problema real se quiere resolver?
# *   ¿Para quién es útil la predicción?
# *   ¿Qué decisión mejora la solución?

# %% [markdown]
# 📌 Descripción clara y breve.

# %% [markdown]
# **Traducción del problema a Machine Learning.**
#
# *   Tipo de tarea.
# *   Tipo de lenguaje de aprendizaje.
# *   Significado de las clases 0/1.

# %% [markdown]
# 📌 Dejar claro qué NO predice el modelo, de forma clara y breve.

# %% [markdown]
# **Definición de la Variable Objetivo (Target).**
#
# *   Cómo se construye el target.
# *   Regla usada.
# *   En qué momento del vuelo se mide.
# *   Por qué esta definición es razonable para el negocio.

# %% [markdown]
# 📌 Escrita de manera clara  simple.

# %% [markdown]
# **Descripción del dataset.**
#
# Como descripción coneptual:
#
# *   Origen de los datos.
# *   Tipo de vuelos.
# *   Qué representa cada fila.
# *   Qué información general contiene las columnas.

# %% [markdown]
# 📌 No un diccionario exhaustivo.

# %% [markdown]
# **Exploración de datos (EDA).**
#
# Como decisiones, no gráficos.
#
# *   Qué se observó relevante.
# *   Problemas detectados (nulos, outliers, sesgos)
# *   Qué cosas influyeron en decisiones posteriores.

# %% [markdown]
# 📌 Documentar conclusiones, No documentar cada gráfico.

# %% [markdown]
# **Preparación de datos.**
#
# *   Cómo se manejaron los valores nulos.
# *   Transformaciones relevantes.
# *   Variables descartadas (por qué).

# %% [markdown]
# 📌 Enfocado en critério, no en código.

# %% [markdown]
# **Feature engineering.**
#
# *   Qué nuevas variables se crearon.
# *   Desde qué fuente de información original.
# *   Por qué ayudan a predecir el retraso.

# %% [markdown]
# 📌 Transformar información operacional simple en señales que el modelo pueda usar **antes del despegue**, sin introducir fuga de información (data leakage)

# %% [markdown]
# Debe quedar explícito que:
#
# *   Las features representan condiciones conocidas antes del vuelo.
# *   No se usan variables que dependan del resultado del vuelo.
# *   Se priorizan features simples, interpretables y robustas.

# %% [markdown]
# **Entrenamiento del modelo.**
#
# Como descripción coneptual pensada para alguien no experto.

# %% [markdown]
# *   Cómo se separaron los datos (train/test)
# *   Qué objetivo tiene el entrenamiento.
# *   Qué se busca evitar.
# *   Lo que se prioriza(simplicidad y estabilidad)

# %% [markdown]
# Debe quedar claro:
#
# *   Que el modelo aprende solo con datos históricos.
# *   El conjunto de test simula vuelos no vistos.
# *   No se ajustan hiperparámetros complejos.
# *   Se privilegia la reproducibilidad.

# %% [markdown]
# 📌 Entrenar un modelo suficientemente bueno para demostrar valor, no optimizar al máximo su desempeño.

# %% [markdown]
# **Selección del modelo**
#
# *   Qué modelo se eligió.
# *   Por qué es adecuado para un MVP.
# *   Qué privilegia (simplicidad, interpretabilidad, rapidez)
# *   Elemento de lista

# %% [markdown]
# 📌 No hace falta comparación extensa de modelos.

# %% [markdown]
# **Evaluación del modelo.**
#
# Como descripción coneptual pensado para **alguien no experto.**
#
# *   Qué métricas se usaron.
# *   Qué significa **"buen desempeño"** en este contexto.
# *   Qué riesgos tiene el modelo.
# *   Elemento de lista

# %% [markdown]
# 📌 Pensado para alguien no experto.

# %% [markdown]
# **Exportación e integración.**
#
# *   Qué archivo se exporta.
# *   Qué representa ese archivo.
# *   Cómo será consumido por la API.
# *   Qué espera el modelo como input y output.

# %% [markdown]
# 📌 Clave para el equipo de backend.

# %% [markdown]
# ## **3. Otras decisiones sobre estructura y documentación.**

# %% [markdown]
# ### **3.1. README del módulo Data Science.**

# %% [markdown]
# Se definió un único `README.md` en el submódulo de Data Science que incluye:
# - Banner de identificación.
# - Estado del proyecto.
# - Descripción del módulo.
# - Alcance del módulo.
# - Explicación del uso de cada carpeta.

# %% [markdown]
# No se crearon archivos README por carpeta para mantener el enfoque MVP y reducir ruido documental.

# %% [markdown]
# ### **3.2. Alcance del trabajo en equipo.**

# %% [markdown]
# El alcance del trabajo en equipo se deja definido en la  sección del alcance del módulo, enumerando las principales etapas del proceso de Data Science abordadas en el proyecto.
#
# Se decidió incluir el alcance del módulo con enlaces directos porque:
#
# * Convierte el README en un **mapa de lectura,** no solo un texto descriptivo.
# * Facilita que cualquier integrante del equipo DS se ubique rápidamente con el contenido de una etapa específica.
# * Permite a un lector externo ir **directamente a la evidencia,** sin necesidad de buscar entre carpetas o archivos.
# * No añade complejidad técnica al repositorio, solo **mejora la navegabilidad.**
# * Refuerza la idea de mantener un repositorio **ordenado, estructurado y desarrollado por etapas.**
#
# Para lo cual se requiere establecer las siguientes reglas:
#
# *   **Un notebook por etapa.**
# *   **No enlaces de notebook intermedios o exploratorios.**
# *   **No cambiar rutas después sin actualizar el README.md**

# %% [markdown]
# ### **3.3. Ubicación de los nombres del equipo.**

# %% [markdown]
# Los nombres de los integrantes del equipo se documentan únicamente en el
# repositorio principal del proyecto.
#
# Esto se decidió porque:
# - El equipo pertenece al proyecto completo, no a un submódulo específico.
# - Evita duplicación de información.
# - Mantiene el README de Data Science enfocado en lo técnico.
