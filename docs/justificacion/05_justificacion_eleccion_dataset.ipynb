# %% [markdown]
# #**Elección del dataset.**

# %% [markdown]
# ✅ Criterios que ya consideraron (correctos)
#
# Los criterios que mencionas son necesarios y bien elegidos:
#
# Contener registros de vuelos comerciales
# ✔️ Alinea el dataset con el problema de negocio.
#
# Tener variables que permitan observar el target
# ✔️ Permite construir la etiqueta de manera objetiva (retraso observado).
#
# Incluir variables explicativas disponibles antes de la salida
# ✔️ Garantiza que el modelo pueda usarse de forma predictiva (no retrospectiva).
#
# Hasta aquí, todo está bien 👍

# %% [markdown]
# 🔍 ¿Qué faltaba explicitar (aunque implícitamente lo hicieron)?
#
# Hay tres criterios adicionales que ya están presentes en tu razonamiento, pero no están nombrados explícitamente como criterios de selección del dataset. Conviene agregarlos porque elevan el nivel del proyecto.

# %% [markdown]
# 4. Coherencia temporal y causal del dataset
#
# Qué significa
#
# El dataset debe permitir separar claramente:
#
# información previa al evento (features), de
#
# información posterior al evento (resultado observado).
#
# Por qué importa
#
# Esto asegura que:
#
# el modelo no “vea el futuro”,
#
# el target no esté contaminado por variables que ocurren después,
#
# la predicción sea válida desde el punto de vista causal.
#
# 📌 Esto conecta directamente con tu decisión de excluir variables como carrier_delay, weather_delay, etc.
#
# 👉 Este criterio es clave y conviene nombrarlo.

# %% [markdown]
# 5. Consistencia con el estándar operativo del negocio
#
# Qué significa
#
# El dataset debe permitir:
#
# aplicar un umbral operativo estándar (15 minutos),
#
# construir el target de forma alineada con métricas reales de la industria.
#
# Por qué importa
#
# Evita:
#
# definiciones arbitrarias,
#
# targets artificiales,
#
# desconexión entre modelo y uso real.
#
# 📌 Aquí estás justificando que el dataset soporta el estándar A15 / D15, no solo que tiene minutos de retraso.

# %% [markdown]
# 6. Escala y representatividad histórica
#
# Qué significa
#
# El dataset debe:
#
# cubrir suficientes vuelos,
#
# abarcar distintos aeropuertos, aerolíneas, horarios y períodos,
#
# reflejar variabilidad real del sistema aeronáutico.
#
# Por qué importa
#
# Esto permite que el modelo:
#
# aprenda patrones generales,
#
# capture estacionalidad y variabilidad,
#
# no quede sobreajustado a un contexto muy limitado.
#
# 📌 No necesitas cifras aún, solo el criterio conceptual.

# %% [markdown]
# Resumen — criterios finales (ya depurados)
#
# Cuando redactes la justificación de elección del dataset, los criterios quedarían así:
#
# Contiene registros históricos de vuelos comerciales.
#
# Incluye variables que permiten observar directamente el resultado operativo del vuelo.
#
# Proporciona variables explicativas disponibles antes del despegue, habilitando predicción real.
#
# Permite una separación temporal y causal clara entre features y target.
#
# Es consistente con estándares operativos de puntualidad usados por la industria.
#
# Presenta volumen y diversidad suficientes para capturar la complejidad del fenómeno.

# %% [markdown]
# **Paso siguiente:**

# %% [markdown]
# Redactar directamente la sección “Justificación de elección del dataset”,
# y luego pasar a Descripción y comprensión del dataset (EDA conceptual)
